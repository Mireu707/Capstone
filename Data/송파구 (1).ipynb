# %%
install.packages("extrafont")
library(extrafont)
system("sudo apt-get install fonts-nanum-coding")
font_import(pattern="Nanum" )
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘extrafontdb’, ‘Rttf2pt1’
#
#
# Registering fonts with R
# Importing fonts may take a few minutes, depending on the number of fonts and the speed of the system.
# Continue? [y/n] y
# Scanning ttf files in /usr/share/fonts/, /usr/local/share/fonts/ ...
#
# Extracting .afm files from .ttf files...
#
# /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf
#  => /usr/local/lib/R/site-library/extrafontdb/metrics/NanumBarunGothic
#
# /usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf
#  => /usr/local/lib/R/site-library/extrafontdb/metrics/NanumBarunGothicBold
#
# /usr/share/fonts/truetype/nanum/NanumGothic.ttf
#  => /usr/local/lib/R/site-library/extrafontdb/metrics/NanumGothic
#
# /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf
#  => /usr/local/lib/R/site-library/extrafontdb/metrics/NanumGothicBold
#
# /usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf
# ...

# %%
library(extrafont)
fonts()
# Out:
# Registering fonts with R
# [1] "NanumBarunGothic"         "NanumGothic"
# [3] "NanumGothicCoding"        "NanumMyeongjo"
# [5] "NanumSquare Bold"         "NanumSquare"
# [7] "NanumSquareRound Bold"    "NanumSquareRound Regular"

# %%
install.packages(c("tidyverse","data.table"))
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
library(data.table)
library(dplyr)

# %% [markdown]
# ## **송파구 1월 전처리**

# %%
#https://drive.google.com/file/d/1uDqSwEQJc5ui_wf45QiQCQJM5bSQxiAC/view?usp=sharing
system("gdown --id 1uDqSwEQJc5ui_wf45QiQCQJM5bSQxiAC")
system("ls",TRUE)
# Out:
# [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
# [2] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
# [3] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
# [4] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
# [5] "공공자전거 대여소 정보(22.12월 기준).csv"
# [6] "공공자전거 대여소 정보(22.12월 기준).xlsx"
# [7] "일자별 날씨정보.csv"
# [8] "sample_data"

# %%
DF01<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_22.01.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF01
# Out:
# Rows: 792649 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대코드, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#        대여일자   대여소번호
# 1      2022-01-01 00102
# 2      2022-01-01 00102
# 3      2022-01-01 00102
# 4      2022-01-01 00102
# 5      2022-01-01 00102
# 6      2022-01-01 00102
# 7      2022-01-01 00102
# 8      2022-01-01 00102
# 9      2022-01-01 00102
# 10     2022-01-01 00102
# 11     2022-01-01 00102
# 12     2022-01-01 00102
# 13     2022-01-01 00102
# 14     2022-01-01 00102
# 15     2022-01-01 00102
# 16     2022-01-01 00102
# 17     2022-01-01 00102
# 18     2022-01-01 00102
# 6     2022-01-01 1201       정기         NA   20대       1
# 7     2022-01-01 1201       정기         F    20대       1
# 8     2022-01-01 1201       정기         F    30대       1
# 9     2022-01-01 1201       정기         F    40대       1
# 10    2022-01-01 1201       정기         F    기타       2
# 11    2022-01-01 1201       정기         M    20대       1
# 12    2022-01-01 1201       정기         M    30대       2
# 13    2022-01-01 1201       정기         M    50대       1
# 14    2022-01-01 1201       정기         M    기타       1
# 15    2022-01-01 1203       일일(회원)   \\N  10대       1
# 16    2022-01-01 1203       일일(회원)   \\N  20대       1
# ...

# %%
selected_DF01$`대여구분코드`<-ifelse(selected_DF01$`대여구분코드`=='정기',1,0)

# %%
selected_DF01 <- selected_DF01 %>%
  mutate(성별 = as.character(성별)) %>%
  mutate(성별 = case_when(
    성별 == "M" ~ 0,
    성별 == "F" ~ 1,
    TRUE ~ 2
  ))
#selected_DF02$`성별`<-ifelse(selected_DF02$`성별`=='M',0,ifelse(selected_DF02$`성별`=='F',1,2))

# %%
#selected_DF01$`연령대코드`<-ifelse(selected_DF01$`연령대코드`==c('10대','20대'),0,ifelse(selected_DF01$`연령대코드`=='30대',1,
#ifelse(selected_DF01$`연령대코드`=='40대',2,ifelse(selected_DF01$`연령대코드`=='50대',3,4))))
selected_DF01 <- selected_DF01 %>%
  mutate(연령대코드 = case_when(
    연령대코드 == "10대" ~ 0,
    연령대코드 == "20대" ~ 0,
    연령대코드 == "30대" ~ 1,
    연령대코드 == "40대" ~ 2,
    연령대코드 == "50대" ~ 3,
    연령대코드 == "60대" ~ 4,
    연령대코드 == "70대이상" ~ 4,
    연령대코드 == "기타" ~ 4,
    TRUE ~ as.numeric(연령대코드) # 숫자로 변환할 수 없는 값은 그대로 유지
  ))
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `연령대코드 = case_when(...)`.
# Caused by warning:
# ! NAs introduced by coercion”

# %%
selected_DF01
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수
# 1     2022-01-01 1201       0            2    3          1
# 2     2022-01-01 1201       1            2    0          4
# 3     2022-01-01 1201       1            2    1          2
# 4     2022-01-01 1201       1            2    2          1
# 5     2022-01-01 1201       1            2    3          1
# 6     2022-01-01 1201       1            2    0          1
# 7     2022-01-01 1201       1            1    0          1
# 8     2022-01-01 1201       1            1    1          1
# 9     2022-01-01 1201       1            1    2          1
# 10    2022-01-01 1201       1            1    4          2
# 11    2022-01-01 1201       1            0    0          1
# 12    2022-01-01 1201       1            0    1          2
# 13    2022-01-01 1201       1            0    3          1
# 14    2022-01-01 1201       1            0    4          1
# 15    2022-01-01 1203       0            2    0          1
# ...

# %%
write.csv(selected_DF01,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.01.csv",row.names=FALSE, na="")

# %%
selected_DF01$'평일/주말' <- ifelse(selected_DF01$대여일자 %in% date$date_time, date$weekend[match(selected_DF01$대여일자, date$date_time)], 2)
selected_DF01
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수 평일/주말
# 1     2022-01-01 1201       0            2    3          1        1
# 2     2022-01-01 1201       1            2    0          4        1
# 3     2022-01-01 1201       1            2    1          2        1
# 4     2022-01-01 1201       1            2    2          1        1
# 5     2022-01-01 1201       1            2    3          1        1
# 6     2022-01-01 1201       1            2    0          1        1
# 7     2022-01-01 1201       1            1    0          1        1
# 8     2022-01-01 1201       1            1    1          1        1
# 9     2022-01-01 1201       1            1    2          1        1
# 10    2022-01-01 1201       1            1    4          2        1
# 11    2022-01-01 1201       1            0    0          1        1
# 12    2022-01-01 1201       1            0    1          2        1
# 13    2022-01-01 1201       1            0    3          1        1
# ...

# %%
selected_DF01 <- selected_DF01 %>% select('평일/주말', '대여구분코드', '성별', '연령대코드', '이용건수')
selected_DF01
# Out:
#       평일/주말 대여구분코드 성별 연령대코드 이용건수
# 1     1         0            2    3          1
# 2     1         1            2    0          4
# 3     1         1            2    1          2
# 4     1         1            2    2          1
# 5     1         1            2    3          1
# 6     1         1            2    0          1
# 7     1         1            1    0          1
# 8     1         1            1    1          1
# 9     1         1            1    2          1
# 10    1         1            1    4          2
# 11    1         1            0    0          1
# 12    1         1            0    1          2
# 13    1         1            0    3          1
# 14    1         1            0    4          1
# 15    1         0            2    0          1
# 16    1         0            2    0          1
# 17    1         0            1    3          1
# 18    1         0            0    1          1
# 19    1         0            0    2          1
# ...

# %%
write.csv(selected_DF01,file="/content/전처리__송파구_서울특별시 공공자전거 이용정보(일별)_22.01.csv",row.names=FALSE, na="")

# %%
selected_DF01%>%
  filter(selected_DF01$`평일/주말`== 0 && selected_DF01$`성별`== 0 && selected_DF01$`연령대코드`== 0 && selected_DF01$`이용건수`== 0 && selected_DF01$`대여구분코드`== 0)
  %>% sum(이용건수, na.rm = TRUE)
# Out:
# Error in parse(text = x, srcfile = src): <text>:3:3: unexpected SPECIAL
# 2:   filter(selected_DF01$`평일/주말`== 0 && selected_DF01$`성별`== 0 && selected_DF01$`연령대코드`== 0 && selected_DF01$`이용건수`== 0 && selected_DF01$`대여구분코드`== 0)
# 3:   %>%
#      ^
# Traceback:

# %%
summarized_data <- selected_DF01 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data
# Out:
#    대여일자   이용건수_합계
# 1  2022-01-01 2595
# 2  2022-01-02 2317
# 3  2022-01-03 4199
# 4  2022-01-04 4544
# 5  2022-01-05 4654
# 6  2022-01-06 5003
# 7  2022-01-07 5027
# 8  2022-01-08 3889
# 9  2022-01-09 3350
# 10 2022-01-10 4923
# 11 2022-01-11 3321
# 12 2022-01-12 3722
# 13 2022-01-13 3579
# 14 2022-01-14 4326
# 15 2022-01-15 3618
# 16 2022-01-16 2814
# 17 2022-01-17 3178
# 18 2022-01-18 3894
# 19 2022-01-19 2197
# 20 2022-01-20 3205
# 21 2022-01-21 4094
# 22 2022-01-22 3700
# 23 2022-01-23 3681
# 24 2022-01-24 5393
# 25 2022-01-25 3806
# 26 2022-01-26 5149
# 27 2022-01-27 4820
# 28 2022-01-28 4613
# 29 2022-01-29 3336
# 30 2022-01-30 2825
# 31 2022-01-31 2552

# %% [markdown]
# ## **송파구 2월 전처리**

# %%
#https://drive.google.com/file/d/1DfhlIGas5mIgqR7Hmm6irq0C4ki6euBn/view?usp=sharing
system("gdown --id 1DfhlIGas5mIgqR7Hmm6irq0C4ki6euBn")
system("ls",TRUE)
# Out:
# [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
# [2] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
# [3] "일자별 날씨정보.csv"
# [4] "sample_data"

# %%
DF02<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_22.02.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF02
# Out:
# Rows: 747394 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대코드, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#        대여일자   대여소번호 대여소
# 1      2022-02-01 00003      중랑센터
# 2      2022-02-01 00102      102. 망원역 1번출구 앞
# 3      2022-02-01 00102      102. 망원역 1번출구 앞
# 4      2022-02-01 00102      102. 망원역 1번출구 앞
# 5      2022-02-01 00102      102. 망원역 1번출구 앞
# 6      2022-02-01 00102      102. 망원역 1번출구 앞
# 7      2022-02-01 00102      102. 망원역 1번출구 앞
# 8      2022-02-01 00102      102. 망원역 1번출구 앞
# 9      2022-02-01 00102      102. 망원역 1번출구 앞
# 10     2022-02-01 00102      102. 망원역 1번출구 앞
# 11     2022-02-01 00102      102. 망원역 1번출구 앞
# 12     2022-02-01 00102      102. 망원역 1번출구 앞
# ...

# %%
DF02$대여소번호 <- as.numeric(DF02$대여소번호)

# %%
#2월 대여소 filter
f_DF02<- DF02 %>% filter(대여소번호 %in% c(1201,1203,1204,1205,1206,1207,1208,1209,1210,1212,1213,1214,1215,1217,1218,1220,1222,1224,1226,1227,1228,
1229,1230,1231,1232,1233,1235,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1253,1256,1257,1258,1259,1260,1262,1263,1264,
1265,1266,1267,1268,1269,1271,1274,1275,1277,1278,1279,1280,1282,1283,1285,1286,1287,1288,1289,1290,1291,1293,1295,1296,1297,1299,1300,2601,
2605,2606,2608,2609,2611,2612,2613,2614,2615,2616,2617,2618,2619,2620,2621,2622,2623,2625,2626,2627,2628,2630,2631,2632,2633,2634,2635,2637,
2639,2641,2642,2643,2644,2645,2646,2647,2648,2649,2650,2651,2652,2653,2654,2655,2656,2657,2658,2659,4458,4460,4461,4462,4463,4464,4465,4467,
4468,4860,4469,4472,4473,4474,4475,4478,4479,4480,4481,4483,4452,4484,4485,4486,4488,4490,4491,4493,4496,4497,4499,4500,4852,4854,4855,4856,4857,
4453,4454,4456,4457,4859,4862,4863,4864,4865,4867,4868,4870,4871,4869,4872,4873,4874,4875,4876,4879,4880,4881,4882,4883,4884,4885,4886,4887,4888,
4889,4891,4892,4893,4895,4896,4897))
f_DF02
# Out:
#       대여일자   대여소번호 대여소                          대여구분코드 성별
# 1     2022-02-01 1201       1201. 가락시장역 3번 출구       일일(회원)   \\N
# 2     2022-02-01 1201       1201. 가락시장역 3번 출구       일일(회원)   M
# 3     2022-02-01 1201       1201. 가락시장역 3번 출구       정기         \\N
# 4     2022-02-01 1201       1201. 가락시장역 3번 출구       정기         \\N
# 5     2022-02-01 1201       1201. 가락시장역 3번 출구       정기         F
# 6     2022-02-01 1201       1201. 가락시장역 3번 출구       정기         M
# 7     2022-02-01 1203       1203. 밀리아나2빌딩 앞          일일(회원)   \\N
# 8     2022-02-01 1203       1203. 밀리아나2빌딩 앞          일일(회원)   M
# 9     2022-02-01 1203       1203. 밀리아나2빌딩 앞          정기         \\N
# 10    2022-02-01 1203       1203. 밀리아나2빌딩 앞          정기         \\N
# 11    2022-02-01 1203       1203. 밀리아나2빌딩 앞          정기         \\N
# 12    2022-02-01 1203       1203. 밀리아나2빌딩 앞          정기         F
# 13    2022-02-01 1203       1203. 밀리아나2빌딩 앞          정기         F
# ...

# %%
selected_DF02 <- f_DF02 %>% select(대여일자, 대여소번호, 대여구분코드, 성별, 연령대코드, 이용건수)
selected_DF02
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수
# 1     2022-02-01 1201       일일(회원)   \\N  40대       1
# 2     2022-02-01 1201       일일(회원)   M    20대       1
# 3     2022-02-01 1201       정기         \\N  40대       1
# 4     2022-02-01 1201       정기         \\N  50대       1
# 5     2022-02-01 1201       정기         F    20대       1
# 6     2022-02-01 1201       정기         M    30대       1
# 7     2022-02-01 1203       일일(회원)   \\N  30대       1
# 8     2022-02-01 1203       일일(회원)   M    기타       1
# 9     2022-02-01 1203       정기         \\N  20대       1
# 10    2022-02-01 1203       정기         \\N  30대       1
# 11    2022-02-01 1203       정기         \\N  50대       1
# 12    2022-02-01 1203       정기         F    20대       1
# 13    2022-02-01 1203       정기         F    30대       1
# 14    2022-02-01 1203       정기         F    기타       1
# 15    2022-02-01 1203       정기         M    20대       1
# 16    2022-02-01 1204       일일(회원)   F    20대       1
# ...

# %%
selected_DF02$`대여구분코드`<-ifelse(selected_DF02$`대여구분코드`=='정기',1,0)

# %%
selected_DF02$`성별`<-ifelse(selected_DF02$`성별`=='M',0,ifelse(selected_DF02$`성별`=='F',1,2))

# %%
selected_DF02$`연령대코드`<-ifelse(selected_DF02$`연령대코드`=='10대',0,ifelse(selected_DF02$`연령대코드`=='20대',1,ifelse(selected_DF02$`연령대코드`=='30대',2,ifelse(selected_DF02$`연령대코드`=='40대',3,ifelse(selected_DF02$`연령대코드`=='50대',4,ifelse(selected_DF02$`연령대코드`=='60대',5,ifelse(selected_DF02$`연령대코드`=='70대이상',6,7)))))))

# %%
selected_DF02
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수
# 1     2022-02-01 1201       0            2    3          1
# 2     2022-02-01 1201       0            0    1          1
# 3     2022-02-01 1201       1            2    3          1
# 4     2022-02-01 1201       1            2    4          1
# 5     2022-02-01 1201       1            1    1          1
# 6     2022-02-01 1201       1            0    2          1
# 7     2022-02-01 1203       0            2    2          1
# 8     2022-02-01 1203       0            0    7          1
# 9     2022-02-01 1203       1            2    1          1
# 10    2022-02-01 1203       1            2    2          1
# 11    2022-02-01 1203       1            2    4          1
# 12    2022-02-01 1203       1            1    1          1
# 13    2022-02-01 1203       1            1    2          1
# 14    2022-02-01 1203       1            1    7          1
# 15    2022-02-01 1203       1            0    1          1
# ...

# %%
write.csv(selected_DF02,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv",row.names=FALSE, na="")

# %%
selected_DF02$'평일/주말' <- ifelse(selected_DF02$대여일자 %in% date$date_time, date$weekend[match(selected_DF02$대여일자, date$date_time)], 2)
selected_DF02
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수 평일/주말
# 1     2022-02-01 1201       0            2    3          1        1
# 2     2022-02-01 1201       0            0    1          1        1
# 3     2022-02-01 1201       1            2    3          1        1
# 4     2022-02-01 1201       1            2    4          1        1
# 5     2022-02-01 1201       1            1    1          1        1
# 6     2022-02-01 1201       1            0    2          1        1
# 7     2022-02-01 1203       0            2    2          1        1
# 8     2022-02-01 1203       0            0    7          1        1
# 9     2022-02-01 1203       1            2    1          1        1
# 10    2022-02-01 1203       1            2    2          1        1
# 11    2022-02-01 1203       1            2    4          1        1
# 12    2022-02-01 1203       1            1    1          1        1
# 13    2022-02-01 1203       1            1    2          1        1
# ...

# %%
colnames(selected_DF02)
# Out:
# [1] "대여일자"     "대여소번호"   "대여구분코드" "성별"         "연령대코드"
# [6] "이용건수"     "평일/주말"

# %%
unique_values <- unique(selected_DF02[c("대여일자", "평일/주말")])
print(unique_values)
# Out:
# # A tibble: 28 × 2
#    대여일자   `평일/주말`
#    <date>           <dbl>
#  1 2022-02-01           2
#  2 2022-02-02           1
#  3 2022-02-03           0
#  4 2022-02-04           0
#  5 2022-02-05           1
#  6 2022-02-06           1
#  7 2022-02-07           0
#  8 2022-02-08           0
#  9 2022-02-09           0
# 10 2022-02-10           0
# # ℹ 18 more rows

# %%
selected_DF02 <- selected_DF02 %>% select('평일/주말', '대여구분코드', '성별', '연령대코드', '이용건수')
selected_DF02
# Out:
#       평일/주말 대여구분코드 성별 연령대코드 이용건수
# 1     1         0            2    3          1
# 2     1         0            0    1          1
# 3     1         1            2    3          1
# 4     1         1            2    4          1
# 5     1         1            1    1          1
# 6     1         1            0    2          1
# 7     1         0            2    2          1
# 8     1         0            0    7          1
# 9     1         1            2    1          1
# 10    1         1            2    2          1
# 11    1         1            2    4          1
# 12    1         1            1    1          1
# 13    1         1            1    2          1
# 14    1         1            1    7          1
# 15    1         1            0    1          1
# 16    1         0            1    1          1
# 17    1         0            0    0          1
# 18    1         1            2    2          2
# 19    1         1            1    3          2
# ...

# %%
summarized_data_02 <- selected_DF02 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data_02
# Out:
#    대여일자   이용건수_합계
# 1  2022-02-01 1337
# 2  2022-02-02 2610
# 3  2022-02-03 3967
# 4  2022-02-04 3779
# 5  2022-02-05 2687
# 6  2022-02-06 2670
# 7  2022-02-07 4341
# 8  2022-02-08 4851
# 9  2022-02-09 5193
# 10 2022-02-10 5609
# 11 2022-02-11 5614
# 12 2022-02-12 5277
# 13 2022-02-13 4545
# 14 2022-02-14 3989
# 15 2022-02-15 4056
# 16 2022-02-16 3525
# 17 2022-02-17 3944
# 18 2022-02-18 4811
# 19 2022-02-19 3749
# 20 2022-02-20 2593
# 21 2022-02-21 4055
# 22 2022-02-22 4031
# 23 2022-02-23 3932
# 24 2022-02-24 4450
# 25 2022-02-25 5219
# 26 2022-02-26 3362
# 27 2022-02-27 4738
# 28 2022-02-28 6107

# %% [markdown]
# ## **송파구 3월 전처리**

# %%
#https://drive.google.com/file/d/1S-VxhDHRQvnbyRpfCYWcFc3d4N9ysDYb/view?usp=sharing
system("gdown --id 1S-VxhDHRQvnbyRpfCYWcFc3d4N9ysDYb")
system("ls",TRUE)
# Out:
# [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
# [2] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
# [3] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
# [4] "일자별 날씨정보.csv"
# [5] "sample_data"

# %%
DF03<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_22.03.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF03
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 1136504 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (5): 대여소번호, 대여소, 대여구분코드, 성별, 연령대코드
# dbl  (5): 이용건수, 운동량, 탄소량, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#         대여일자   대여소번호 대여소                       대여구분코드 성별
# 1       2022-03-01 00003      중랑센터                     정기         M
# 2       2022-03-01 00003      중랑센터                     정기         M
# 3       2022-03-01 00102      102. 망원역 1번출구 앞       일일(회원)   \\N
# 4       2022-03-01 00102      102. 망원역 1번출구 앞       일일(회원)   \\N
# 5       2022-03-01 00102      102. 망원역 1번출구 앞       일일(회원)   NA
# ...

# %%
 DF03$대여소번호 <- as.numeric(DF03$대여소번호)

# %%
f_DF03<-DF03%>% filter(대여소번호 %in% c(1201,1203,1204,1205,1206,1207,1208,1209,1210,1212,1213,1214,1215,1217,1218,1220,1222,1224,1226,1227,1228,
1229,1230,1231,1232,1233,1235,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1253,1256,1257,1258,1259,1260,1262,1263,1264,
1265,1266,1267,1268,1269,1271,1274,1275,1277,1278,1279,1280,1282,1283,1285,1286,1287,1288,1289,1290,1291,1293,1295,1296,1297,1299,1300,2601,
2605,2606,2608,2609,2611,2612,2613,2614,2615,2616,2617,2618,2619,2620,2621,2622,2623,2625,2626,2627,2628,2630,2631,2632,2633,2634,2635,2637,
# %%
selected_DF03$`성별`<-ifelse(selected_DF03$`성별`=='M',0,ifelse(selected_DF03$`성별`=='F',1,2))

# %%
selected_DF03$`연령대코드`<-ifelse(selected_DF03$`연령대코드`=='10대',0,ifelse(selected_DF03$`연령대코드`=='20대',1,ifelse(selected_DF03$`연령대코드`=='30대',2,ifelse(selected_DF03$`연령대코드`=='40대',3,ifelse(selected_DF03$`연령대코드`=='50대',4,ifelse(selected_DF03$`연령대코드`=='60대',5,ifelse(selected_DF03$`연령대코드`=='70대이상',6,7)))))))

# %%
selected_DF03
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수
# 1     2022-03-01 1201       0             2   1          4
# 2     2022-03-01 1201       0             2   2          1
# 3     2022-03-01 1201       0             2   3          1
# 4     2022-03-01 1201       0             1   1          1
# 5     2022-03-01 1201       0             1   2          1
# 6     2022-03-01 1201       0             0   1          1
# 7     2022-03-01 1201       0             0   3          1
# 8     2022-03-01 1201       0             0   7          1
# 9     2022-03-01 1201       1             2   1          2
# 10    2022-03-01 1201       1             2   2          1
# 11    2022-03-01 1201       1             2   3          2
# 12    2022-03-01 1201       1             2   4          4
# 13    2022-03-01 1201       1            NA   2          1
# 14    2022-03-01 1201       1            NA   5          1
# 15    2022-03-01 1201       1             1   1          3
# ...

# %%
write.csv(selected_DF03,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv",row.names=FALSE, na="")

# %%
selected_DF03$'평일/주말' <- ifelse(selected_DF03$대여일자 %in% date$date_time, date$weekend[match(selected_DF03$대여일자, date$date_time)], 2)
selected_DF03
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수 평일/주말
# 1     2022-03-01 1201       0             2   1          4        1
# 2     2022-03-01 1201       0             2   2          1        1
# 3     2022-03-01 1201       0             2   3          1        1
# 4     2022-03-01 1201       0             1   1          1        1
# 5     2022-03-01 1201       0             1   2          1        1
# 6     2022-03-01 1201       0             0   1          1        1
# 7     2022-03-01 1201       0             0   3          1        1
# 8     2022-03-01 1201       0             0   7          1        1
# 9     2022-03-01 1201       1             2   1          2        1
# 10    2022-03-01 1201       1             2   2          1        1
# 11    2022-03-01 1201       1             2   3          2        1
# 12    2022-03-01 1201       1             2   4          4        1
# 13    2022-03-01 1201       1            NA   2          1        1
# ...

# %%
selected_DF03 <- selected_DF03 %>% select('평일/주말', '대여구분코드', '성별', '연령대코드', '이용건수')
selected_DF03
# Out:
#       평일/주말 대여구분코드 성별 연령대코드 이용건수
# 1     1         0             2   1          4
# 2     1         0             2   2          1
# 3     1         0             2   3          1
# 4     1         0             1   1          1
# 5     1         0             1   2          1
# 6     1         0             0   1          1
# 7     1         0             0   3          1
# 8     1         0             0   7          1
# 9     1         1             2   1          2
# 10    1         1             2   2          1
# 11    1         1             2   3          2
# 12    1         1             2   4          4
# 13    1         1            NA   2          1
# 14    1         1            NA   5          1
# 15    1         1             1   1          3
# 16    1         1             1   2          3
# 17    1         1             1   4          1
# 18    1         1             1   7          2
# 19    1         1             0   0          1
# ...

# %%
summarized_data_03 <- selected_DF03 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data_03
# Out:
#    대여일자   이용건수_합계
# 1  2022-03-01 4531
# 2  2022-03-02 5751
# 3  2022-03-03 6389
# 4  2022-03-04 6045
# 5  2022-03-05 4971
# 6  2022-03-06 4869
# 7  2022-03-07 6039
# 8  2022-03-08 6781
# 9  2022-03-09 7872
# 10 2022-03-10 7406
# 11 2022-03-11 8147
# 12 2022-03-12 7332
# 13 2022-03-13 3222
# 14 2022-03-14 3958
# 15 2022-03-15 7589
# 16 2022-03-16 8151
# 17 2022-03-17 6186
# 18 2022-03-18 6555
# 19 2022-03-19 2823
# 20 2022-03-20 5646
# 21 2022-03-21 6962
# 22 2022-03-22 8018
# 23 2022-03-23 7189
# 24 2022-03-24 7660
# 25 2022-03-25 6933
# 26 2022-03-26 5480
# 27 2022-03-27 7942
# 28 2022-03-28 8918
# 29 2022-03-29 9494
# 30 2022-03-30 7807
# 31 2022-03-31 9397

# %% [markdown]
# ## **4월 전처리**

# %%
#https://drive.google.com/file/d/1LIJ-8Jjo5V1LyE6gra-mv2LRUTsv6LIp/view?usp=sharing
system("gdown --id 1LIJ-8Jjo5V1LyE6gra-mv2LRUTsv6LIp")
system("ls",TRUE)
# Out:
# [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
# [2] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
# [3] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
# [4] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
# [5] "일자별 날씨정보.csv"
# [6] "sample_data"

# %%
DF04<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_22.04.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF04
# Out:
# Rows: 1487586 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대코드, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#         대여일자   대여소번호 대여소                       대여구분코드 성별
# 1       2022-04-01 00005      상암센터 정비실              정기         F
# 2       2022-04-01 00005      상암센터 정비실              정기         M
# 3       2022-04-01 00102      102. 망원역 1번출구 앞       단체         M
# 4       2022-04-01 00102      102. 망원역 1번출구 앞       일일(비회원) \\N
# 5       2022-04-01 00102      102. 망원역 1번출구 앞       일일(회원)   \\N
# 6       2022-04-01 00102      102. 망원역 1번출구 앞       일일(회원)   \\N
# 7       2022-04-01 00102      102. 망원역 1번출구 앞       일일(회원)   \\N
# 8       2022-04-01 00102      102. 망원역 1번출구 앞       일일(회원)   NA
# ...

# %%
DF04$대여소번호 <- as.numeric(DF04$대여소번호)

# %%
f_DF04<-DF04%>% filter(대여소번호 %in% c(1201,1203,1204,1205,1206,1207,1208,1209,1210,1212,1213,1214,1215,1217,1218,1220,1222,1224,1226,1227,1228,
# 9      2022-04-01 1201       일일(회원)   M    50대        1
# 10     2022-04-01 1201       정기         \\N  20대        5
# 11     2022-04-01 1201       정기         \\N  30대       11
# 12     2022-04-01 1201       정기         \\N  40대        4
# 13     2022-04-01 1201       정기         \\N  50대        3
# 14     2022-04-01 1201       정기         NA   40대        2
# 15     2022-04-01 1201       정기         F    20대        4
# 16     2022-04-01 1201       정기         F    30대        9
# ...

# %%
selected_DF04$`대여구분코드`<-ifelse(selected_DF04$`대여구분코드`=='정기',1,0)

# %%
selected_DF04$`성별`<-ifelse(selected_DF04$`성별`=='M',0,ifelse(selected_DF04$`성별`=='F',1,2))

# %%
selected_DF04$`연령대코드`<-ifelse(selected_DF04$`연령대코드`=='10대',0,ifelse(selected_DF04$`연령대코드`=='20대',1,
ifelse(selected_DF04$`연령대코드`=='30대',2,ifelse(selected_DF04$`연령대코드`=='40대',3,ifelse(selected_DF04$`연령대코드`=='50대',4,
ifelse(selected_DF04$`연령대코드`=='60대',5,ifelse(selected_DF04$`연령대코드`=='70대이상',6,7)))))))

# %%
selected_DF04
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수
# 1      2022-04-01 1201       0             2   7           1
# 2      2022-04-01 1201       0             2   1           4
# 3      2022-04-01 1201       0             2   2           3
# 4      2022-04-01 1201       0            NA   2           1
# 5      2022-04-01 1201       0             1   2           1
# 6      2022-04-01 1201       0             1   3           1
# 7      2022-04-01 1201       0             1   7           1
# 8      2022-04-01 1201       0             0   2           2
# 9      2022-04-01 1201       0             0   4           1
# 10     2022-04-01 1201       1             2   1           5
# 11     2022-04-01 1201       1             2   2          11
# 12     2022-04-01 1201       1             2   3           4
# 13     2022-04-01 1201       1             2   4           3
# 14     2022-04-01 1201       1            NA   3           2
# 15     2022-04-01 1201       1             1   1           4
# ...

# %%
write.csv(selected_DF04,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.04.csv",row.names=FALSE, na="")

# %%
selected_DF04$'평일/주말' <- ifelse(selected_DF04$대여일자 %in% date$date_time, date$weekend[match(selected_DF04$대여일자, date$date_time)], 2)
selected_DF04
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수 평일/주말
# 1      2022-04-01 1201       0             2   7           1       0
# 2      2022-04-01 1201       0             2   1           4       0
# 3      2022-04-01 1201       0             2   2           3       0
# 4      2022-04-01 1201       0            NA   2           1       0
# 5      2022-04-01 1201       0             1   2           1       0
# 6      2022-04-01 1201       0             1   3           1       0
# 7      2022-04-01 1201       0             1   7           1       0
# 8      2022-04-01 1201       0             0   2           2       0
# 9      2022-04-01 1201       0             0   4           1       0
# 10     2022-04-01 1201       1             2   1           5       0
# 11     2022-04-01 1201       1             2   2          11       0
# 12     2022-04-01 1201       1             2   3           4       0
# 13     2022-04-01 1201       1             2   4           3       0
# ...

# %%
selected_DF04 <- selected_DF04 %>% select('평일/주말', '대여구분코드', '성별', '연령대코드', '이용건수')
selected_DF04
# Out:
#        평일/주말 대여구분코드 성별 연령대코드 이용건수
# 1      0         0             2   7           1
# 2      0         0             2   1           4
# 3      0         0             2   2           3
# 4      0         0            NA   2           1
# 5      0         0             1   2           1
# 6      0         0             1   3           1
# 7      0         0             1   7           1
# 8      0         0             0   2           2
# 9      0         0             0   4           1
# 10     0         1             2   1           5
# 11     0         1             2   2          11
# 12     0         1             2   3           4
# 13     0         1             2   4           3
# 14     0         1            NA   3           2
# 15     0         1             1   1           4
# 16     0         1             1   2           9
# 17     0         1             1   3           4
# 18     0         1             1   5           2
# ...

# %%
summarized_data_04 <- selected_DF04 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data_04
# Out:
#    대여일자   이용건수_합계
# 1  2022-04-01 10384
# 2  2022-04-02 10142
# 3  2022-04-03 11015
# 4  2022-04-04 10356
# 5  2022-04-05 10736
# 6  2022-04-06 11537
# 7  2022-04-07 11373
# 8  2022-04-08 13396
# 9  2022-04-09 15153
# 10 2022-04-10 15429
# 11 2022-04-11 13688
# 12 2022-04-12 11123
# 13 2022-04-13  6252
# 14 2022-04-14 10249
# 15 2022-04-15 12408
# 16 2022-04-16 12348
# 17 2022-04-17 12412
# 18 2022-04-18 12133
# 19 2022-04-19 13056
# 20 2022-04-20 13008
# 21 2022-04-21 12982
# 22 2022-04-22 11639
# 23 2022-04-23 13405
# 24 2022-04-24 12404
# 25 2022-04-25 11139
# 26 2022-04-26 13293
# 27 2022-04-27 13707
# 28 2022-04-28 13713
# 29 2022-04-29 10364
# 30 2022-04-30 11479

# %% [markdown]
# ## **5월 전처리**

# %%
#https://drive.google.com/file/d/1H5rGpyiNy0up_6heh8O_YVBAxy8e5fAT/view?usp=sharing
system("gdown --id 1H5rGpyiNy0up_6heh8O_YVBAxy8e5fAT")
system("ls",TRUE)
# Out:
# [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
# [2] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
# [3] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv"
# [4] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
# [5] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv"
# [6] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
# [7] "서울특별시 공공자전거 이용정보(일별)_22.05.csv"
# [8] "sample_data"

# %%
DF05<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_22.05.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF05
# Out:
# Rows: 1669729 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대코드, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#         대여일자   대여소번호 대여소                    대여구분코드   성별
# 1       2022-05-01 00003      중랑센터                  정기권         M
# 2       2022-05-01 00102      102. 망원역 1번출구 앞    단체권         \\N
# 3       2022-05-01 00102      102. 망원역 1번출구 앞    단체권         \\N
# 4       2022-05-01 00102      102. 망원역 1번출구 앞    단체권         F
# 5       2022-05-01 00102      102. 망원역 1번출구 앞    일일권(비회원) \\N
# 6       2022-05-01 00102      102. 망원역 1번출구 앞    일일권         \\N
# 7       2022-05-01 00102      102. 망원역 1번출구 앞    일일권         \\N
# 8       2022-05-01 00102      102. 망원역 1번출구 앞    일일권         \\N
# ...

# %%
DF05$대여소번호 <- as.numeric(DF05$대여소번호)

# %%
f_DF05<-DF05%>% filter(대여소번호 %in% c(1201,1203,1204,1205,1206,1207,1208,1209,1210,1212,1213,1214,1215,1217,1218,1220,1222,1224,1226,1227,1228,
1229,1230,1231,1232,1233,1235,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1253,1256,1257,1258,1259,1260,1262,1263,1264,
1265,1266,1267,1268,1269,1271,1274,1275,1277,1278,1279,1280,1282,1283,1285,1286,1287,1288,1289,1290,1291,1293,1295,1296,1297,1299,1300,2601,
2605,2606,2608,2609,2611,2612,2613,2614,2615,2616,2617,2618,2619,2620,2621,2622,2623,2625,2626,2627,2628,2630,2631,2632,2633,2634,2635,2637,
2639,2641,2642,2643,2644,2645,2646,2647,2648,2649,2650,2651,2652,2653,2654,2655,2656,2657,2658,2659,4458,4460,4461,4462,4463,4464,4465,4467,
4468,4860,4469,4472,4473,4474,4475,4478,4479,4480,4481,4483,4452,4484,4485,4486,4488,4490,4491,4493,4496,4497,4499,4500,4852,4854,4855,4856,4857,
4453,4454,4456,4457,4859,4862,4863,4864,4865,4867,4868,4870,4871,4869,4872,4873,4874,4875,4876,4879,4880,4881,4882,4883,4884,4885,4886,4887,4888,
4889,4891,4892,4893,4895,4896,4897,5751,5752,5753,5760,5756,5758,5759,5761,5763,5764,5765,5766,5767))
f_DF05
# Out:
#        대여일자   대여소번호 대여소                         대여구분코드   성별
# 1      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권(비회원) \\N
# 2      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권         \\N
# 3      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권         \\N
# 4      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권         \\N
# 5      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권         F
# 6      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권         F
# 7      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권         F
# 8      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권         M
# 9      2022-05-01 1201       1201. 가락시장역 3번 출구      일일권         M
# 10     2022-05-01 1201       1201. 가락시장역 3번 출구      정기권         \\N
# 11     2022-05-01 1201       1201. 가락시장역 3번 출구      정기권         \\N
# 12     2022-05-01 1201       1201. 가락시장역 3번 출구      정기권         \\N
# 13     2022-05-01 1201       1201. 가락시장역 3번 출구      정기권         \\N
# ...

# %%
selected_DF05 <- f_DF05 %>% select(대여일자, 대여소번호, 대여구분코드, 성별, 연령대코드, 이용건수)
selected_DF05
# Out:
#        대여일자   대여소번호 대여구분코드   성별 연령대코드 이용건수
# 1      2022-05-01 1201       일일권(비회원) \\N  기타        2
# 2      2022-05-01 1201       일일권         \\N  20대        3
# 3      2022-05-01 1201       일일권         \\N  30대        1
# 4      2022-05-01 1201       일일권         \\N  기타        1
# 5      2022-05-01 1201       일일권         F    10대        2
# 6      2022-05-01 1201       일일권         F    20대        1
# 7      2022-05-01 1201       일일권         F    30대        2
# 8      2022-05-01 1201       일일권         M    10대        4
# 9      2022-05-01 1201       일일권         M    30대        3
# 10     2022-05-01 1201       정기권         \\N  10대        1
# 11     2022-05-01 1201       정기권         \\N  20대        5
# 12     2022-05-01 1201       정기권         \\N  30대       12
# 13     2022-05-01 1201       정기권         \\N  40대        1
# 14     2022-05-01 1201       정기권         \\N  50대        1
# 15     2022-05-01 1201       정기권         F    20대        6
# ...

# %%
selected_DF05$`대여구분코드`<- ifelse(selected_DF05$`대여구분코드`=='정기권',1,0)

# %%
selected_DF05$`성별`<-ifelse(selected_DF05$`성별`=='M',0,ifelse(selected_DF05$`성별`=='F',1,2))

# %%
selected_DF05$`연령대코드`<-ifelse(selected_DF05$`연령대코드`=='10대',0,ifelse(selected_DF05$`연령대코드`=='20대',1,
ifelse(selected_DF05$`연령대코드`=='30대',2,ifelse(selected_DF05$`연령대코드`=='40대',3,ifelse(selected_DF05$`연령대코드`=='50대',4,
ifelse(selected_DF05$`연령대코드`=='60대',5,ifelse(selected_DF05$`연령대코드`=='70대이상',6,7)))))))

# %%
selected_DF05
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수
# 1      2022-05-01 1201       0            2    7           2
# 2      2022-05-01 1201       0            2    1           3
# 3      2022-05-01 1201       0            2    2           1
# 4      2022-05-01 1201       0            2    7           1
# 5      2022-05-01 1201       0            1    0           2
# 6      2022-05-01 1201       0            1    1           1
# 7      2022-05-01 1201       0            1    2           2
# 8      2022-05-01 1201       0            0    0           4
# 9      2022-05-01 1201       0            0    2           3
# 10     2022-05-01 1201       1            2    0           1
# 11     2022-05-01 1201       1            2    1           5
# 12     2022-05-01 1201       1            2    2          12
# 13     2022-05-01 1201       1            2    3           1
# 14     2022-05-01 1201       1            2    4           1
# 15     2022-05-01 1201       1            1    1           6
# ...

# %%
write.csv(selected_DF05,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.05.csv",row.names=FALSE, na="")

# %%
selected_DF05$'평일/주말' <- ifelse(selected_DF05$대여일자 %in% date$date_time, date$weekend[match(selected_DF05$대여일자, date$date_time)], 2)
selected_DF05
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수 평일/주말
# 1      2022-05-01 1201       0            2    7           2       1
# 2      2022-05-01 1201       0            2    1           3       1
# 3      2022-05-01 1201       0            2    2           1       1
# 4      2022-05-01 1201       0            2    7           1       1
# 5      2022-05-01 1201       0            1    0           2       1
# 6      2022-05-01 1201       0            1    1           1       1
# 7      2022-05-01 1201       0            1    2           2       1
# 8      2022-05-01 1201       0            0    0           4       1
# 9      2022-05-01 1201       0            0    2           3       1
# 10     2022-05-01 1201       1            2    0           1       1
# 11     2022-05-01 1201       1            2    1           5       1
# 12     2022-05-01 1201       1            2    2          12       1
# 13     2022-05-01 1201       1            2    3           1       1
# ...

# %%
selected_DF05 <- selected_DF05 %>% select('평일/주말', '대여구분코드', '성별', '연령대코드', '이용건수')
selected_DF05
# Out:
#        평일/주말 대여구분코드 성별 연령대코드 이용건수
# 1      1         0            2    7           2
# 2      1         0            2    1           3
# 3      1         0            2    2           1
# 4      1         0            2    7           1
# 5      1         0            1    0           2
# 6      1         0            1    1           1
# 7      1         0            1    2           2
# 8      1         0            0    0           4
# 9      1         0            0    2           3
# 10     1         1            2    0           1
# 11     1         1            2    1           5
# 12     1         1            2    2          12
# 13     1         1            2    3           1
# 14     1         1            2    4           1
# 15     1         1            1    1           6
# 16     1         1            1    2           2
# 17     1         1            1    3           1
# 18     1         1            1    4           2
# ...

# %%
summarized_data_05 <- selected_DF05 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data_05
# Out:
#    대여일자   이용건수_합계
# 1  2022-05-01 11691
# 2  2022-05-02 13337
# 3  2022-05-03 14107
# 4  2022-05-04 15143
# 5  2022-05-05 15204
# 6  2022-05-06 14865
# 7  2022-05-07 13199
# 8  2022-05-08  7852
# 9  2022-05-09 14482
# 10 2022-05-10 15366
# 11 2022-05-11 15168
# 12 2022-05-12 15460
# 13 2022-05-13 15815
# 14 2022-05-14 14295
# 15 2022-05-15 14254
# 16 2022-05-16 14562
# 17 2022-05-17 15330
# 18 2022-05-18 13436
# 19 2022-05-19 15238
# 20 2022-05-20 15929
# 21 2022-05-21 14657
# 22 2022-05-22 13887
# 23 2022-05-23 14321
# 24 2022-05-24 15672
# 25 2022-05-25 12272
# 26 2022-05-26 15349
# 27 2022-05-27 17067
# 28 2022-05-28 15883
# 29 2022-05-29 14163
# 30 2022-05-30 14127
# 31 2022-05-31 16460

# %% [markdown]
# ## **6월 전처리**

# %%
#https://drive.google.com/file/d/1rqmBkWRneMg3Oy10xLNn_JEz3TXNrBHm/view?usp=sharing
system("gdown --id 1rqmBkWRneMg3Oy10xLNn_JEz3TXNrBHm")
system("ls",TRUE)
# Out:
#  [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [2] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [3] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [4] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [5] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [6] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
#  [7] "서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [8] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [9] "서울특별시 공공자전거 이용정보(일별)_22.06.csv"
# [10] "sample_data"

# %%
DF06<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_22.06.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF06
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 1475868 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  
# 11     2022-06-01 1201       1201. 가락시장역 3번 출구
# 12     2022-06-01 1201       1201. 가락시장역 3번 출구
# 13     2022-06-01 1201       1201. 가락시장역 3번 출구
# 14     2022-06-01 1201       1201. 가락시장역 3번 출구
# 15     2022-06-01 1201       1201. 가락시장역 3번 출구
# 16     2022-06-01 1201       1201. 가락시장역 3번 출구
# 17     2022-06-01 1201       1201. 가락시장역 3번 출구
# 18     2022-06-01 1201       1201. 가락시장역 3번 출구
# 19     2022-06-01 1201       1201. 가락시장역 3번 출구
# ...

# %%
selected_DF06 <- f_DF06 %>% select(대여일자, 대여소번호, 대여구분코드, 성별, 연령대코드, 이용건수)
selected_DF06
# Out:
#        대여일자   대여소번호 대여구분코드   성별 연령대코드 이용건수
# 1      2022-06-01 1201       단체권         M    40대        3
# 2      2022-06-01 1201       일일권(비회원) \\N  기타        1
# 3      2022-06-01 1201       일일권(비회원) F    기타        1
# 4      2022-06-01 1201       일일권         \\N  20대        9
# 5      2022-06-01 1201       일일권         \\N  30대        7
# 6      2022-06-01 1201       일일권         \\N  40대        1
# 7      2022-06-01 1201       일일권         F    10대        1
# 8      2022-06-01 1201       일일권         F    20대        2
# 9      2022-06-01 1201       일일권         F    30대        1
# 10     2022-06-01 1201       일일권         F    40대        1
# 11     2022-06-01 1201       일일권         F    기타        1
# 12     2022-06-01 1201       일일권         M    20대        4
# 13     2022-06-01 1201       일일권         M    30대        5
# 14     2022-06-01 1201       일일권         M    40대        1
# 15     2022-06-01 1201       일일권         M    기타        1
# ...

# %%
selected_DF06$`대여구분코드`<-ifelse(selected_DF06$`대여구분코드`=='정기권',1,0)

# %%
selected_DF06$`성별`<-ifelse(selected_DF06$`성별`=='M',0,ifelse(selected_DF06$`성별`=='F',1,2))

# %%
selected_DF06$`연령대코드`<-ifelse(selected_DF06$`연령대코드`=='10대',0,ifelse(selected_DF06$`연령대코드`=='20대',1,
ifelse(selected_DF06$`연령대코드`=='30대',2,ifelse(selected_DF06$`연령대코드`=='40대',3,ifelse(selected_DF06 $`연령대코드`=='50대',4,
ifelse(selected_DF06$`연령대코드`=='60대',5,ifelse(selected_DF06$`연령대코드`=='70대이상',6,7)))))))

# %%
selected_DF06
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수
# 1      2022-06-01 1201       0            0    3           3
# 2      2022-06-01 1201       0            2    7           1
# 3      2022-06-01 1201       0            1    7           1
# 4      2022-06-01 1201       0            2    1           9
# 5      2022-06-01 1201       0            2    2           7
# 6      2022-06-01 1201       0            2    3           1
# 7      2022-06-01 1201       0            1    0           1
# 8      2022-06-01 1201       0            1    1           2
# 9      2022-06-01 1201       0            1    2           1
# 10     2022-06-01 1201       0            1    3           1
# 11     2022-06-01 1201       0            1    7           1
# 12     2022-06-01 1201       0            0    1           4
# 13     2022-06-01 1201       0            0    2           5
# 14     2022-06-01 1201       0            0    3           1
# 15     2022-06-01 1201       0            0    7           1
# ...

# %%
write.csv(selected_DF06,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.06.csv",row.names=FALSE, na="")

# %%
selected_DF06$'평일/주말' <- ifelse(selected_DF06$대여일자 %in% date$date_time, date$weekend[match(selected_DF06$대여일자, date$date_time)], 2)
selected_DF06
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대코드 이용건수 평일/주말
# 1      2022-06-01 1201       0            0    3           3       1
# 2      2022-06-01 1201       0            2    7           1       1
# 3      2022-06-01 1201       0            1    7           1       1
# 4      2022-06-01 1201       0            2    1           9       1
# 5      2022-06-01 1201       0            2    2           7       1
# 6      2022-06-01 1201       0            2    3           1       1
# 7      2022-06-01 1201       0            1    0           1       1
# 8      2022-06-01 1201       0            1    1           2       1
# 9      2022-06-01 1201       0            1    2           1       1
# 10     2022-06-01 1201       0            1    3           1       1
# 11     2022-06-01 1201       0            1    7           1       1
# 12     2022-06-01 1201       0            0    1           4       1
# 13     2022-06-01 1201       0            0    2           5       1
# ...

# %%
selected_DF06 <- selected_DF06 %>% select('평일/주말', '대여구분코드', '성별', '연령대코드', '이용건수')
selected_DF06
# Out:
#        평일/주말 대여구분코드 성별 연령대코드 이용건수
# 1      1         0            0    3           3
# 2      1         0            2    7           1
# 3      1         0            1    7           1
# 4      1         0            2    1           9
# 5      1         0            2    2           7
# 6      1         0            2    3           1
# 7      1         0            1    0           1
# 8      1         0            1    1           2
# 9      1         0            1    2           1
# 10     1         0            1    3           1
# 11     1         0            1    7           1
# 12     1         0            0    1           4
# 13     1         0            0    2           5
# 14     1         0            0    3           1
# 15     1         0            0    7           1
# 16     1         1            2    1          10
# 17     1         1            2    2          10
# 18     1         1            2    3           3
# ...

# %%
summarized_data_06 <- selected_DF06 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data_06
# Out:
#    대여일자   이용건수_합계
# 1  2022-06-01 15998
# 2  2022-06-02 15081
# 3  2022-06-03 15674
# 4  2022-06-04 14631
# 5  2022-06-05 11030
# 6  2022-06-06 13085
# 7  2022-06-07 15815
# 8  2022-06-08 15982
# 9  2022-06-09 14056
# 10 2022-06-10 14371
# 11 2022-06-11 14836
# 12 2022-06-12 13733
# 13 2022-06-13 14918
# 14 2022-06-14 13183
# 15 2022-06-15  5332
# 16 2022-06-16 13352
# 17 2022-06-17 16292
# 18 2022-06-18 14272
# 19 2022-06-19 13107
# 20 2022-06-20 15530
# 21 2022-06-21 15362
# 22 2022-06-22 15384
# 23 2022-06-23  5107
# 24 2022-06-24 13718
# 25 2022-06-25 13235
# 26 2022-06-26 11099
# 27 2022-06-27  8014
# 28 2022-06-28 11001
# 29 2022-06-29  4529
# 30 2022-06-30   785

# %% [markdown]
# ## **7월 전처리**

# %%
#https://drive.google.com/file/d/1qqaS9AfVJvDd4FH0fniZTMxujGKjEXC2/view?usp=sharing
system("gdown --id 1qqaS9AfVJvDd4FH0fniZTMxujGKjEXC2")
system("ls",TRUE)
# Out:
#  [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [2] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [3] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [4] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [5] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [6] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
#  [7] "서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [8] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [9] "서울특별시 공공자전거 이용정보(일별)_22.06.csv"
# [10] "서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [11] "sample_data"

# %%
DF07<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_22.07.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF07
# Out:
# Rows: 1877903 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#         대여일자   대여소번호 대여소
# 1       2022-07-01 00731      731. 서울시 도로환경관리센터
# 2       2022-07-01 00733      733. 신정이펜하우스314동
# 3       2022-07-01 00734      734. 신트리공원 입구
# 4       2022-07-01 00735      735. 영도초등학교
# 5       2022-07-01 00739      739. 신월사거리
# 6       2022-07-01 00742      742. 등촌역 5번 출구 뒤
# 7       2022-07-01 00745      745. 강서초등학교
# 8       2022-07-01 00746      746. 목동2단지 상가
# 9       2022-07-01 00505      505. 자양사거리 광진아크로텔 앞
# 10      2022-07-01 00942      942. 상림마을 생태공원
# 11      2022-07-01 00947      947. 연신내 선일하이츠빌 정류소
# 12      2022-07-01 00950      950. 구산역 2번 출구 예일여고 버스정류장
# ...

# %%
DF07$대여소번호 <- as.numeric(DF07$대여소번호)

# %%
f_DF07<-DF07%>% filter(대여소번호 %in% c(1201,1203,1204,1205,1206,1207,1208,1209,1210,1212,1213,1214,1215,1217,1218,1220,1222,1224,1226,1227,1228,
1229,1230,1231,1232,1233,1235,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1253,1256,1257,1258,1259,1260,1262,1263,1264,
1265,1266,1267,1268,1269,1271,1274,1275,1277,1278,1279,1280,1282,1283,1285,1286,1287,1288,1289,1290,1291,1293,1295,1296,1297,1299,1300,2601,
2605,2606,2608,2609,2611,2612,2613,2614,2615,2616,2617,2618,2619,2620,2621,2622,2623,2625,2626,2627,2628,2630,2631,2632,2633,2634,2635,2637,
2639,2641,2642,2643,2644,2645,2646,2647,2648,2649,2650,2651,2652,2653,2654,2655,2656,2657,2658,2659,4458,4460,4461,4462,4463,4464,4465,4467,
4468,4860,4469,4472,4473,4474,4475,4478,4479,4480,4481,4483,4452,4484,4485,4486,4488,4490,4491,4493,4496,4497,4499,4500,4852,4854,4855,4856,4857,
4453,4454,4456,4457,4859,4862,4863,4864,4865,4867,4868,4870,4871,4869,4872,4873,4874,4875,4876,4879,4880,4881,4882,4883,4884,4885,4886,4887,4888,
4889,4891,4892,4893,4895,4896,4897,5751,5752,5753,5760,5756,5758,5759,5761,5763,5764,5765,5766,5767))
f_DF07
# Out:
#        대여일자   대여소번호 대여소                               대여구분코드
# 1      2022-07-01 1251       1251. 석촌역 2번출구                 정기권
# 2      2022-07-01 1271       1271. 송파도서관                     정기권
# 3      2022-07-01 1282       1282. 송파소방서 맞은편(성내4교)     정기권
# 4      2022-07-01 1293       1293. 석촌호수 서호 사거리           정기권
# 5      2022-07-01 2621       2621. 한성백제역 2번 출구            정기권
# 6      2022-07-01 2620       2620. 송파나루역 4번 출구옆          정기권
# 7      2022-07-01 2630       2630.서울방이동 고분군               정기권
# 8      2022-07-01 2647       2647.잠실 자전거 수리센터 앞         정기권
# 9      2022-07-01 2648       2648.헬리오시티 112동 앞             정기권
# 10     2022-07-01 2655       2655.송이공원                        정기권
# 11     2022-07-01 4461       4461. 한양3차아파트 3동 앞           정기권
# 12     2022-07-01 4465       4465. 건영아파트앞 사거리            정기권
# 13     2022-07-01 4467       4467. 한림연예예술고등학교           정기권
# 14     2022-07-01 4478       4478. 문정근린공원2                  정기권
# ...

# %%
selected_DF07 <- f_DF07 %>% select(대여일자, 대여소번호, 대여구분코드, 성별, 연령대, 이용건수)
selected_DF07
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대   이용건수
# 1      2022-07-01 1251       정기권       NA   ~10대     1
# 2      2022-07-01 1271       정기권       NA   ~10대     1
# 3      2022-07-01 1282       정기권       NA   ~10대     1
# 4      2022-07-01 1293       정기권       NA   ~10대     1
# 5      2022-07-01 2621       정기권       NA   ~10대     1
# 6      2022-07-01 2620       정기권       NA   ~10대     3
# 7      2022-07-01 2630       정기권       NA   ~10대     2
# 8      2022-07-01 2647       정기권       NA   ~10대     1
# 9      2022-07-01 2648       정기권       NA   ~10대     2
# 10     2022-07-01 2655       정기권       NA   ~10대     2
# 11     2022-07-01 4461       정기권       NA   ~10대     1
# 12     2022-07-01 4465       정기권       NA   ~10대     1
# 13     2022-07-01 4467       정기권       NA   ~10대     1
# 14     2022-07-01 4478       정기권       NA   ~10대     1
# 15     2022-07-01 4491       정기권       NA   ~10대     1
# 16     2022-07-01 4493       정기권       NA   ~10대     1
# ...

# %%
selected_DF07$`대여구분코드`<-ifelse(selected_DF07$`대여구분코드`=='정기권',1,0)

# %%
selected_DF07$`성별`<-ifelse(selected_DF07$`성별`=='M',0,ifelse(selected_DF01$`성별`=='F',1,2))

# %%
selected_DF07$`연령대`<-ifelse(selected_DF07$`연령대`=='~10대',0,ifelse(selected_DF07$`연령대`=='20대',1,
ifelse(selected_DF07$`연령대`=='30대',2,ifelse(selected_DF07$`연령대`=='40대',3,ifelse(selected_DF07$`연령대`=='50대',4,
ifelse(selected_DF07$`연령대`=='60대',5,ifelse(selected_DF07$`연령대`=='70대이상',6,7)))))))

# %%
selected_DF07
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수
# 1      2022-07-01 1251       1            NA   0       1
# 2      2022-07-01 1271       1            NA   0       1
# 3      2022-07-01 1282       1            NA   0       1
# 4      2022-07-01 1293       1            NA   0       1
# 5      2022-07-01 2621       1            NA   0       1
# 6      2022-07-01 2620       1            NA   0       3
# 7      2022-07-01 2630       1            NA   0       2
# 8      2022-07-01 2647       1            NA   0       1
# 9      2022-07-01 2648       1            NA   0       2
# 10     2022-07-01 2655       1            NA   0       2
# 11     2022-07-01 4461       1            NA   0       1
# 12     2022-07-01 4465       1            NA   0       1
# 13     2022-07-01 4467       1            NA   0       1
# 14     2022-07-01 4478       1            NA   0       1
# 15     2022-07-01 4491       1            NA   0       1
# 16     2022-07-01 4493       1            NA   0       1
# ...

# %%
write.csv(selected_DF07,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.07.csv",row.names=FALSE, na="")

# %%
selected_DF07$'평일/주말' <- ifelse(selected_DF07$대여일자 %in% date$date_time, date$weekend[match(selected_DF07$대여일자, date$date_time)], 2)
selected_DF07
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수 평일/주말
# 1      2022-07-01 1251       1            NA   0       1       0
# 2      2022-07-01 1271       1            NA   0       1       0
# 3      2022-07-01 1282       1            NA   0       1       0
# 4      2022-07-01 1293       1            NA   0       1       0
# 5      2022-07-01 2621       1            NA   0       1       0
# 6      2022-07-01 2620       1            NA   0       3       0
# 7      2022-07-01 2630       1            NA   0       2       0
# 8      2022-07-01 2647       1            NA   0       1       0
# 9      2022-07-01 2648       1            NA   0       2       0
# 10     2022-07-01 2655       1            NA   0       2       0
# 11     2022-07-01 4461       1            NA   0       1       0
# 12     2022-07-01 4465       1            NA   0       1       0
# 13     2022-07-01 4467       1            NA   0       1       0
# 14     2022-07-01 4478       1            NA   0       1       0
# ...

# %%
selected_DF07 <- selected_DF07 %>% select('평일/주말', '대여구분코드', '성별', '연령대', '이용건수')
selected_DF07
# Out:
#        평일/주말 대여구분코드 성별 연령대 이용건수
# 1      0         1            NA   0       1
# 2      0         1            NA   0       1
# 3      0         1            NA   0       1
# 4      0         1            NA   0       1
# 5      0         1            NA   0       1
# 6      0         1            NA   0       3
# 7      0         1            NA   0       2
# 8      0         1            NA   0       1
# 9      0         1            NA   0       2
# 10     0         1            NA   0       2
# 11     0         1            NA   0       1
# 12     0         1            NA   0       1
# 13     0         1            NA   0       1
# 14     0         1            NA   0       1
# 15     0         1            NA   0       1
# 16     0         1            NA   0       1
# 17     0         1            NA   0       1
# 18     0         1            NA   0       1
# 19     0         1            NA   0       1
# 20     0         1            NA   0       2
# ...

# %%
summarized_data_07 <- selected_DF07 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data_07
# Out:
#    대여일자   이용건수_합계
# 1  2022-07-01 13849
# 2  2022-07-02 11868
# 3  2022-07-03  9920
# 4  2022-07-04 12717
# 5  2022-07-05 11972
# 6  2022-07-06 12426
# 7  2022-07-07 10477
# 8  2022-07-08 13563
# 9  2022-07-09 12213
# 10 2022-07-10  9253
# 11 2022-07-11 11765
# 12 2022-07-12 14389
# 13 2022-07-13  1758
# 14 2022-07-14 13404
# 15 2022-07-15 15178
# 16 2022-07-16  7983
# 17 2022-07-17 11633
# 18 2022-07-18 14314
# 19 2022-07-19 14150
# 20 2022-07-20 12628
# 21 2022-07-21  8510
# 22 2022-07-22 12452
# 23 2022-07-23  7400
# 24 2022-07-24  9724
# 25 2022-07-25 12596
# 26 2022-07-26 13759
# 27 2022-07-27 13648
# 28 2022-07-28 13198
# 29 2022-07-29 12648
# 30 2022-07-30  9234
# 31 2022-07-31  2522

# %% [markdown]
# ## **8월 전처리**

# %%
#https://drive.google.com/file/d/13wqd65Ldzco32g5tSYWjQRRslhAwZtkH/view?usp=sharing
system("gdown --id 13wqd65Ldzco32g5tSYWjQRRslhAwZtkH")
system("ls",TRUE)
# Out:
#  [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [2] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [3] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [4] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [5] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [6] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
#  [7] "서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [8] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [9] "서울특별시 공공자전거 이용정보(일별)_22.06.csv"
# [10] "서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [11] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [12] "서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [13] "sample_data"

# %%
DF08<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_22.08.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF08
# Out:
# Rows: 1717135 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#         대여일자   대여소번호 대여소
# 1       2022-08-01 00731      731. 서울시 도로환경관리센터
# 2       2022-08-01 00734      734. 신트리공원 입구
# 3       2022-08-01 00735      735. 영도초등학교
# 4       2022-08-01 00740      740. 으뜸공원
# 5       2022-08-01 00746      746. 목동2단지 상가
# 6       2022-08-01 00746      746. 목동2단지 상가
# 7       2022-08-01 00748      748. 목동운동장
# 8       2022-08-01 00949      949. 연신내역 1번 출구
# 9       2022-08-01 00950      950. 구산역 2번 출구 예일여고 버스정류장
# 10      2022-08-01 00953      953. 서울연신초등학교
# 11      2022-08-01 01023      1023. 한국종합기술사옥 앞
# 12      2022-08-01 01041      1041. 묘곡초등학교
# ...

# %%
DF08$대여소번호 <- as.numeric(DF08$대여소번호)

# %%
# 10     2022-08-01 2642       정기권       NA   ~10대  1
# 11     2022-08-01 2625       정기권       NA   ~10대  1
# 12     2022-08-01 2628       정기권       NA   ~10대  1
# 13     2022-08-01 2630       정기권       NA   ~10대  2
# 14     2022-08-01 2646       정기권       NA   ~10대  1
# 15     2022-08-01 2657       정기권       NA   ~10대  2
# 16     2022-08-01 4452       정기권       NA   ~10대  1
# 17     2022-08-01 4457       정기권       NA   ~10대  1
# ...

# %%
selected_DF08$`대여구분코드`<-ifelse(selected_DF08$`대여구분코드`=='정기권',1,0)

# %%
selected_DF08$`성별`<-ifelse(selected_DF08$`성별`=='M',0,ifelse(selected_DF08$`성별`=='F',1,2))

# %%
selected_DF08$`연령대`<-ifelse(selected_DF08$`연령대`=='~10대',0,ifelse(selected_DF08$`연령대`=='20대',1,
ifelse(selected_DF08$`연령대`=='30대',2,ifelse(selected_DF08$`연령대`=='40대',3,ifelse(selected_DF08$`연령대`=='50대',4,
ifelse(selected_DF08$`연령대`=='60대',5,ifelse(selected_DF08$`연령대`=='70대이상',6,7)))))))

# %%
selected_DF08
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수
# 1      2022-08-01 1260       1            NA   0      1
# 2      2022-08-01 1263       1            NA   0      1
# 3      2022-08-01 1275       1            NA   0      2
# 4      2022-08-01 1282       1            NA   0      1
# 5      2022-08-01 2606       1            NA   0      1
# 6      2022-08-01 2608       1            NA   0      1
# 7      2022-08-01 2614       1            NA   0      1
# 8      2022-08-01 2622       1            NA   0      1
# 9      2022-08-01 2620       1            NA   0      1
# 10     2022-08-01 2642       1            NA   0      1
# 11     2022-08-01 2625       1            NA   0      1
# 12     2022-08-01 2628       1            NA   0      1
# 13     2022-08-01 2630       1            NA   0      2
# 14     2022-08-01 2646       1            NA   0      1
# 15     2022-08-01 2657       1            NA   0      2
# 16     2022-08-01 4452       1            NA   0      1
# ...

# %%
write.csv(selected_DF08,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.08.csv",row.names=FALSE, na="")

# %%
selected_DF08$'평일/주말' <- ifelse(selected_DF08$대여일자 %in% date$date_time, date$weekend[match(selected_DF08$대여일자, date$date_time)], 2)
selected_DF08
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수 평일/주말
# 1      2022-08-01 1260       1            NA   0      1        0
# 2      2022-08-01 1263       1            NA   0      1        0
# 3      2022-08-01 1275       1            NA   0      2        0
# 4      2022-08-01 1282       1            NA   0      1        0
# 5      2022-08-01 2606       1            NA   0      1        0
# 6      2022-08-01 2608       1            NA   0      1        0
# 7      2022-08-01 2614       1            NA   0      1        0
# 8      2022-08-01 2622       1            NA   0      1        0
# 9      2022-08-01 2620       1            NA   0      1        0
# 10     2022-08-01 2642       1            NA   0      1        0
# 11     2022-08-01 2625       1            NA   0      1        0
# 12     2022-08-01 2628       1            NA   0      1        0
# 13     2022-08-01 2630       1            NA   0      2        0
# 14     2022-08-01 2646       1            NA   0      1        0
# ...

# %%
selected_DF08 <- selected_DF08 %>% select('평일/주말', '대여구분코드', '성별', '연령대', '이용건수')
selected_DF08
# Out:
#        평일/주말 대여구분코드 성별 연령대 이용건수
# 1      0         1            NA   0      1
# 2      0         1            NA   0      1
# 3      0         1            NA   0      2
# 4      0         1            NA   0      1
# 5      0         1            NA   0      1
# 6      0         1            NA   0      1
# 7      0         1            NA   0      1
# 8      0         1            NA   0      1
# 9      0         1            NA   0      1
# 10     0         1            NA   0      1
# 11     0         1            NA   0      1
# 12     0         1            NA   0      1
# 13     0         1            NA   0      2
# 14     0         1            NA   0      1
# 15     0         1            NA   0      2
# 16     0         1            NA   0      1
# 17     0         1            NA   0      1
# 18     0         1            NA   0      2
# 19     0         1            NA   0      1
# 20     0         1            NA   0      1
# 21     0         1            NA   0      1
# ...

# %%
summarized_data_08 <- selected_DF08 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data_08
# Out:
#    대여일자   이용건수_합계
# 1  2022-08-01  9862
# 2  2022-08-02  6010
# 3  2022-08-03  9297
# 4  2022-08-04 12536
# 5  2022-08-05 12366
# 6  2022-08-06  8715
# 7  2022-08-07  8497
# 8  2022-08-08  1866
# 9  2022-08-09    24
# 10 2022-08-10  8662
# 11 2022-08-11  8545
# 12 2022-08-12 12475
# 13 2022-08-13  7975
# 14 2022-08-14  7617
# 15 2022-08-15  7468
# 16 2022-08-16 13021
# 17 2022-08-17 13391
# 18 2022-08-18 13962
# 19 2022-08-19  6913
# 20 2022-08-20 11604
# 21 2022-08-21 10997
# 22 2022-08-22 12667
# 23 2022-08-23 12718
# 24 2022-08-24 14958
# 25 2022-08-25 10993
# 26 2022-08-26 15222
# 27 2022-08-27 16519
# 28 2022-08-28 15478
# 29 2022-08-29  9258
# 30 2022-08-30  1274
# 31 2022-08-31 14077

# %% [markdown]
# ## **9월 전처리**

# %%
 #https://drive.google.com/file/d/1OohUX0yKk61WomlhmV9bfbqcF4gGiO14/view?usp=sharing
system("gdown --id 1OohUX0yKk61WomlhmV9bfbqcF4gGiO14")
system("ls",TRUE)
# Out:
#  [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [2] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [3] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [4] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [5] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [6] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [7] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
#  [8] "서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [9] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.05.csv"
# [10] "서울특별시 공공자전거 이용정보(일별)_22.06.csv"
# [11] "서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [12] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [13] "서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [14] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [15] "서울특별시 공공자전거 이용정보(일별)_2209.csv"
# [16] "sample_data"

# %%
DF09<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_2209.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF09
# Out:
# Rows: 2050121 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#         대여일자   대여소번호 대여소
# 1       2022-09-01 00729      729. 서부식자재마트 건너편
# 2       2022-09-01 00733      733. 신정이펜하우스314동
# 3       2022-09-01 00734      734. 신트리공원 입구
# 4       2022-09-01 00735      735. 영도초등학교
# 5       2022-09-01 00736      736. 오솔길공원
# 6       2022-09-01 00742      742. 등촌역 5번 출구 뒤
# 7       2022-09-01 00746      746. 목동2단지 상가
# 8       2022-09-01 00747      747. 목동3단지 상가
# 9       2022-09-01 00748      748. 목동운동장
# 10      2022-09-01 00505      505. 자양사거리 광진아크로텔 앞
# 11      2022-09-01 00946      946. 독바위역
# 12      2022-09-01 00948      948. 디지털미디어 시티역 4번출구(DMC역)
# ...

# %%
DF09$대여소번호 <- as.numeric(DF09$대여소번호)

# %%
f_DF09<-DF09%>% filter(대여소번호 %in% c(1201,1203,1204,1205,1206,1207,1208,1209,1210,1212,1213,1214,1215,1217,1218,1220,1222,1224,1226,1227,1228,
1229,1230,1231,1232,1233,1235,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1253,1256,1257,1258,1259,1260,1262,1263,1264,
1265,1266,1267,1268,1269,1271,1274,1275,1277,1278,1279,1280,1282,1283,1285,1286,1287,1288,1289,1290,1291,1293,1295,1296,1297,1299,1300,2601,
2605,2606,2608,2609,2611,2612,2613,2614,2615,2616,2617,2618,2619,2620,2621,2622,2623,2625,2626,2627,2628,2630,2631,2632,2633,2634,2635,2637,
2639,2641,2642,2643,2644,2645,2646,2647,2648,2649,2650,2651,2652,2653,2654,2655,2656,2657,2658,2659,4458,4460,4461,4462,4463,4464,4465,4467,
4468,4860,4469,4472,4473,4474,4475,4478,4479,4480,4481,4483,4452,4484,4485,4486,4488,4490,4491,4493,4496,4497,4499,4500,4852,4854,4855,4856,4857,
4453,4454,4456,4457,4859,4862,4863,4864,4865,4867,4868,4870,4871,4869,4872,4873,4874,4875,4876,4879,4880,4881,4882,4883,4884,4885,4886,4887,4888,
4889,4891,4892,4893,4895,4896,4897,5751,5752,5753,5760,5756,5758,5759,5761,5763,5764,5765,5766,5767))
f_DF09
# Out:
#        대여일자   대여소번호 대여소
# 1      2022-09-01 1251       1251. 석촌역 2번출구
# 2      2022-09-01 1260       1260. 방이동 한양3차아파트 옆
# 3      2022-09-01 1264       1264. 천호역 10번 출구 앞
# 4      2022-09-01 1265       1265. 문정동 근린공원
# 5      2022-09-01 1269       1269. 리센츠아파트
# 6      2022-09-01 1275       1275. 거여초등학교 옆
# 7      2022-09-01 1277       1277. 성내6교
# 8      2022-09-01 1288       1288. 문정중교 사거리
# 9      2022-09-01 1295       1295. 잠실역 8번출구
# 10     2022-09-01 1299       1299. 송파소방서 (방이119안전센터)
# 11     2022-09-01 2601       2601. 석촌호수 아뜰리에
# 12     2022-09-01 2606       2606. 위례동주민센터 맞은편 근린공원
# 13     2022-09-01 2615       2615. 테라타워2
# 14     2022-09-01 2621       2621. 한성백제역 2번 출구
# 15     2022-09-01 2620       2620. 송파나루역 4번 출구옆
# 16     2022-09-01 2644       2644. 성내5교
# 17     2022-09-01 2623       2623.석촌동 주민센터
# 18     2022-09-01 2630       2630.서울방이동 고분군
# 19     2022-09-01 2632       2632.석촌고분역 2번 출구
# 20     2022-09-01 2633       2633.송파학사 옆
# ...

# %%
selected_DF09<- f_DF09 %>% select(대여일자, 대여소번호, 대여구분코드, 성별, 연령대, 이용건수)
selected_DF09
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수
# 1      2022-09-01 1251       정기권       NA   ~10대  1
# 2      2022-09-01 1260       정기권       NA   ~10대  1
# 3      2022-09-01 1264       정기권       NA   ~10대  3
# 4      2022-09-01 1265       정기권       NA   ~10대  1
# 5      2022-09-01 1269       정기권       NA   ~10대  3
# 6      2022-09-01 1275       정기권       NA   ~10대  1
# 7      2022-09-01 1277       정기권       NA   ~10대  1
# 8      2022-09-01 1288       정기권       NA   ~10대  2
# 9      2022-09-01 1295       정기권       NA   ~10대  1
# 10     2022-09-01 1299       정기권       NA   ~10대  2
# 11     2022-09-01 2601       정기권       NA   ~10대  1
# 12     2022-09-01 2606       정기권       NA   ~10대  2
# 13     2022-09-01 2615       정기권       NA   ~10대  1
# 14     2022-09-01 2621       정기권       NA   ~10대  1
# 15     2022-09-01 2620       정기권       NA   ~10대  1
# 16     2022-09-01 2644       정기권       NA   ~10대  2
# 17     2022-09-01 2623       정기권       NA   ~10대  1
# ...

# %%
selected_DF09$`대여구분코드`<-ifelse(selected_DF09$`대여구분코드`=='정기권',1,0)

# %%
selected_DF09$`성별`<-ifelse(selected_DF09$`성별`=='M',0,ifelse(selected_DF09$`성별`=='F',1,2))

# %%
selected_DF09$`연령대`<-ifelse(selected_DF09$`연령대`=='~10대',0,ifelse(selected_DF09$`연령대`=='20대',1,
ifelse(selected_DF09$`연령대`=='30대',2,ifelse(selected_DF09$`연령대`=='40대',3,ifelse(selected_DF09$`연령대`=='50대',4,
ifelse(selected_DF09$`연령대`=='60대',5,ifelse(selected_DF09$`연령대`=='70대이상',6,7)))))))

# %%
selected_DF09
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수
# 1      2022-09-01 1251       1            NA   0      1
# 2      2022-09-01 1260       1            NA   0      1
# 3      2022-09-01 1264       1            NA   0      3
# 4      2022-09-01 1265       1            NA   0      1
# 5      2022-09-01 1269       1            NA   0      3
# 6      2022-09-01 1275       1            NA   0      1
# 17 2022-09-17 14211
# 18 2022-09-18 14118
# 19 2022-09-19 15710
# 20 2022-09-20 16667
# 21 2022-09-21 16302
# 22 2022-09-22 16171
# 23 2022-09-23 15743
# 24 2022-09-24 17244
# 25 2022-09-25 15638
# 26 2022-09-26 16438
# 27 2022-09-27 16622
# 28 2022-09-28 16924
# 29 2022-09-29 16342
# 30 2022-09-30 17501

# %% [markdown]
# ## **10월 전처리**

# %%
#https://drive.google.com/file/d/1i_FcB4v9OB3skmhy1rh95-BN7zfGE8Fm/view?usp=sharing
system("gdown --id 1i_FcB4v9OB3skmhy1rh95-BN7zfGE8Fm")
system("ls",TRUE)
# Out:
#  [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [2] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [3] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [4] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [5] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [6] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [7] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
#  [8] "서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [9] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.05.csv"
# [10] "서울특별시 공공자전거 이용정보(일별)_22.06.csv"
# [11] "서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [12] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [13] "서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [14] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [15] "서울특별시 공공자전거 이용정보(일별)_2209.csv"
# [16] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.09.csv"
# [17] "서울특별시 공공자전거 이용정보(일별)_2210.csv"
# [18] "sample_data"

# %%
DF10<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_2210.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF10
# Out:
# Rows: 2022901 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#         대여일자   대여소번호 대여소                            대여구분코드
# 1       2022-10-01 00108      108. 서교동 사거리                정기권
# 2       2022-10-01 00729      729. 서부식자재마트 건너편        정기권
# 3       2022-10-01 00729      729. 서부식자재마트 건너편        정기권
# 4       2022-10-01 00731      731. 서울시 도로환경관리센터      정기권
# 5       2022-10-01 00733      733. 신정이펜하우스314동          정기권
# 6       2022-10-01 00735      735. 영도초등학교                 정기권
# 7       2022-10-01 00736      736. 오솔길공원                   정기권
# 8       2022-10-01 00739      739. 신월사거리                   정기권
# ...

# %%
DF10$대여소번호 <- as.numeric(DF10$대여소번호)

# %%
# 7      2022-10-01 1282       정기권       NA   ~10대  1
# 8      2022-10-01 1286       정기권       NA   ~10대  1
# 9      2022-10-01 1288       정기권       NA   ~10대  2
# 10     2022-10-01 1293       정기권       NA   ~10대  1
# 11     2022-10-01 1295       정기권       NA   ~10대  1
# 12     2022-10-01 2611       정기권       NA   ~10대  2
# 13     2022-10-01 2622       정기권       NA   ~10대  2
# 14     2022-10-01 2618       정기권       NA   ~10대  1
# 15     2022-10-01 2620       정기권       NA   ~10대  2
# 16     2022-10-01 2642       정기권       NA   ~10대  1
# 17     2022-10-01 2628       정기권       NA   ~10대  2
# ...

# %%
selected_DF10$`대여구분코드`<-ifelse(selected_DF10$`대여구분코드`=='정기권',1,0)

# %%
selected_DF10$`성별`<-ifelse(selected_DF10$`성별`=='M',0,ifelse(selected_DF10$`성별`=='F',1,2))

# %%
selected_DF10$`연령대`<-ifelse(selected_DF10$`연령대`=='~10대',0,ifelse(selected_DF10$`연령대`=='20대',1,
ifelse(selected_DF10$`연령대`=='30대',2,ifelse(selected_DF10$`연령대`=='40대',3,ifelse(selected_DF10$`연령대`=='50대',4,
ifelse(selected_DF10$`연령대`=='60대',5,ifelse(selected_DF10$`연령대`=='70대이상',6,7)))))))

# %%
selected_DF10
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수
# 1      2022-10-01 1256       1            NA   0      1
# 2      2022-10-01 1268       1            NA   0      1
# 3      2022-10-01 1271       1            NA   0      1
# 4      2022-10-01 1275       1            NA   0      1
# 5      2022-10-01 1277       1            NA   0      1
# 6      2022-10-01 1278       1            NA   0      2
# 7      2022-10-01 1282       1            NA   0      1
# 8      2022-10-01 1286       1            NA   0      1
# 9      2022-10-01 1288       1            NA   0      2
# 10     2022-10-01 1293       1            NA   0      1
# 11     2022-10-01 1295       1            NA   0      1
# 12     2022-10-01 2611       1            NA   0      2
# 13     2022-10-01 2622       1            NA   0      2
# 14     2022-10-01 2618       1            NA   0      1
# 15     2022-10-01 2620       1            NA   0      2
# 16     2022-10-01 2642       1            NA   0      1
# ...

# %%
selected_DF10$'평일/주말' <- ifelse(selected_DF10$대여일자 %in% date$date_time, date$weekend[match(selected_DF10$대여일자, date$date_time)], 2)
selected_DF10
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수 평일/주말
# 1      2022-10-01 1256       1            NA   0      1        1
# 2      2022-10-01 1268       1            NA   0      1        1
# 3      2022-10-01 1271       1            NA   0      1        1
# 4      2022-10-01 1275       1            NA   0      1        1
# 5      2022-10-01 1277       1            NA   0      1        1
# 6      2022-10-01 1278       1            NA   0      2        1
# 7      2022-10-01 1282       1            NA   0      1        1
# 8      2022-10-01 1286       1            NA   0      1        1
# 9      2022-10-01 1288       1            NA   0      2        1
# 10     2022-10-01 1293       1            NA   0      1        1
# 11     2022-10-01 1295       1            NA   0      1        1
# 12     2022-10-01 2611       1            NA   0      2        1
# 13     2022-10-01 2622       1            NA   0      2        1
# 14     2022-10-01 2618       1            NA   0      1        1
# ...

# %%
selected_DF10 <- selected_DF10 %>% select('평일/주말', '대여구분코드', '성별', '연령대', '이용건수')
selected_DF10
# Out:
#        평일/주말 대여구분코드 성별 연령대 이용건수
# 1      1         1            NA   0      1
# 2      1         1            NA   0      1
# 3      1         1            NA   0      1
# 4      1         1            NA   0      1
# 5      1         1            NA   0      1
# 6      1         1            NA   0      2
# 7      1         1            NA   0      1
# 8      1         1            NA   0      1
# 9      1         1            NA   0      2
# 10     1         1            NA   0      1
# 11     1         1            NA   0      1
# 12     1         1            NA   0      2
# 13     1         1            NA   0      2
# 14     1         1            NA   0      1
# 15     1         1            NA   0      2
# 16     1         1            NA   0      1
# 17     1         1            NA   0      2
# 18     1         1            NA   0      1
# 19     1         1            NA   0      1
# 20     1         1            NA   0      2
# 21     1         1            NA   0      3
# ...

# %% [markdown]
# ## **11월 전처리**

# %%
#https://drive.google.com/file/d/1v3-HFpDhcxC2637f87s1b6-3ncglBFVW/view?usp=sharing
system("gdown --id 1v3-HFpDhcxC2637f87s1b6-3ncglBFVW")
system("ls",TRUE)
# Out:
#  [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [2] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.01.csv"
#  [3] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [4] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [5] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [6] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [7] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
#  [8] "서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [9] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.05.csv"
# [10] "서울특별시 공공자전거 이용정보(일별)_22.06.csv"
# [11] "서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [12] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [13] "서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [14] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [15] "서울특별시 공공자전거 이용정보(일별)_2209.csv"
# [16] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.09.csv"
# [17] "서울특별시 공공자전거 이용정보(일별)_2210.csv"
# [18] "서울특별시 공공자전거 이용정보(일별)_2211.csv"
# [19] "sample_data"

# %%
DF11<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_2211.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF11
# Out:
# Rows: 1848895 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# 20     2022-11-01 4468       4468. 가락1동주민센터
# ...

# %%
selected_DF11 <- f_DF11 %>% select(대여일자, 대여소번호, 대여구분코드, 성별, 연령대, 이용건수)
selected_DF11
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수
# 1      2022-11-01 1251       정기권       NA   ~10대  1
# 2      2022-11-01 1260       정기권       NA   ~10대  2
# 3      2022-11-01 1264       정기권       NA   ~10대  2
# 4      2022-11-01 1265       정기권       NA   ~10대  1
# 5      2022-11-01 1267       정기권       NA   ~10대  1
# 6      2022-11-01 1274       정기권       NA   ~10대  2
# 7      2022-11-01 1278       정기권       NA   ~10대  1
# 8      2022-11-01 1293       정기권       NA   ~10대  1
# 9      2022-11-01 2611       정기권       NA   ~10대  1
# 10     2022-11-01 2617       정기권       NA   ~10대  1
# 11     2022-11-01 2620       정기권       NA   ~10대  2
# 12     2022-11-01 2630       정기권       NA   ~10대  1
# 13     2022-11-01 2632       정기권       NA   ~10대  1
# 14     2022-11-01 2647       정기권       NA   ~10대  1
# 15     2022-11-01 2651       정기권       NA   ~10대  2
# 16     2022-11-01 4457       정기권       NA   ~10대  2
# 17     2022-11-01 4458       정기권       NA   ~10대  1
# ...

# %%
selected_DF11$`대여구분코드`<-ifelse(selected_DF11$`대여구분코드`=='정기권',1,0)

# %%
selected_DF11$`성별`<-ifelse(selected_DF11$`성별`=='M',0,ifelse(selected_DF11$`성별`=='F',1,2))

# %%
selected_DF11$`연령대`<-ifelse(selected_DF11$`연령대`=='~10대',0,ifelse(selected_DF11$`연령대`=='20대',1,
ifelse(selected_DF11$`연령대`=='30대',2,ifelse(selected_DF11$`연령대`=='40대',3,ifelse(selected_DF11$`연령대`=='50대',4,
ifelse(selected_DF11$`연령대`=='60대',5,ifelse(selected_DF11$`연령대`=='70대이상',6,7)))))))

# %%
selected_DF11
# Out:
#        대여일자   대여소번호 대여구분코드 성별 연령대 이용건수
# 1      2022-11-01 1251       1            NA   0      1
# 2      2022-11-01 1260       1            NA   0      2
# 3      2022-11-01 1264       1            NA   0      2
# 4      2022-11-01 1265       1            NA   0      1
# 5      2022-11-01 1267       1            NA   0      1
# 6      2022-11-01 1274       1            NA   0      2
# 7      2022-11-01 1278       1            NA   0      1
# 8      2022-11-01 1293       1            NA   0      1
# 9      2022-11-01 2611       1            NA   0      1
# 10     2022-11-01 2617       1            NA   0      1
# 11     2022-11-01 2620       1            NA   0      2
# 12     2022-11-01 2630       1            NA   0      1
# 13     2022-11-01 2632       1            NA   0      1
# 14     2022-11-01 2647       1            NA   0      1
# 15     2022-11-01 2651       1            NA   0      2
# 16     2022-11-01 4457       1            NA   0      2
# ...

# %%
write.csv(selected_DF11,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.11.csv",row.names=FALSE, na="")

# %%
selected_DF11$'평일/주말' <- ifelse(selected_DF11$대여일자 %in% date$date_time, date$weekend[match(selected_DF11$대여일자, date$date_time)], 2)
selected_DF11
# Out:
#  [3] "서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [4] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.02.csv"
#  [5] "서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [6] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.03.csv"
#  [7] "서울특별시 공공자전거 이용정보(일별)_22.04.csv"
#  [8] "서울특별시 공공자전거 이용정보(일별)_22.05.csv"
#  [9] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.05.csv"
# [10] "서울특별시 공공자전거 이용정보(일별)_22.06.csv"
# [11] "서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [12] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.07.csv"
# [13] "서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [14] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.08.csv"
# [15] "서울특별시 공공자전거 이용정보(일별)_2209.csv"
# [16] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.09.csv"
# [17] "서울특별시 공공자전거 이용정보(일별)_2210.csv"
# [18] "서울특별시 공공자전거 이용정보(일별)_2211.csv"
# [19] "전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.11.csv"
# [20] "서울특별시 공공자전거 이용정보(일별)_2212.csv"
# [21] "sample_data"

# %%
DF12<- read_csv("/content/서울특별시 공공자전거 이용정보(일별)_2212.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
DF12
# Out:
# Rows: 1074746 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): 대여소번호, 대여소, 대여구분코드, 성별, 연령대, 운동량, 탄소량
# dbl  (3): 이용건수, 이동거리(M), 이용시간(분)
# date (1): 대여일자
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#         대여일자   대여소번호 대여소
# 1       2022-12-01 00729      729. 서부식자재마트 건너편
# 2       2022-12-01 00735      735. 영도초등학교
# 3       2022-12-01 00739      739. 신월사거리
# 4       2022-12-01 00741      741. 화곡로 입구 교차로
# 5       2022-12-01 00746      746. 목동2단지 상가
# 6       2022-12-01 00937      937. 상림마을 롯데캐슬2단지 옆
# 7       2022-12-01 00950      950. 구산역 2번 출구 예일여고 버스정류장
# 8       2022-12-01 01023      1023. 한국종합기술사옥 앞
# 9       2022-12-01 01025      1025. 상일초등학교
# 10      2022-12-01 01029      1029. 성내어울터
# 11      2022-12-01 01035      1035. 고덕역 4번출구
# 12      2022-12-01 01036      1036. 고덕동 주양쇼핑
# ...

# %%
DF12$대여소번호 <- as.numeric(DF12$대여소번호)

# %%
f_DF12<-DF12%>% filter(대여소번호 %in% c(1201,1203,1204,1205,1206,1207,1208,1209,1210,1212,1213,1214,1215,1217,1218,1220,1222,1224,1226,1227,1228,
1229,1230,1231,1232,1233,1235,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1253,1256,1257,1258,1259,1260,1262,1263,1264,
1265,1266,1267,1268,1269,1271,1274,1275,1277,1278,1279,1280,1282,1283,1285,1286,1287,1288,1289,1290,1291,1293,1295,1296,1297,1299,1300,2601,
# ...

# %%
selected_DF12$`대여구분코드`<-ifelse(selected_DF12$`대여구분코드`=='정기권',1,0)

# %%
selected_DF12$`성별`<-ifelse(selected_DF12$`성별`=='M',0,ifelse(selected_DF12$`성별`=='F',1,2))

# %%
selected_DF12$`연령대`<-ifelse(selected_DF12$`연령대`=='~10대',0,ifelse(selected_DF12$`연령대`=='20대',1,
ifelse(selected_DF12$`연령대`=='30대',2,ifelse(selected_DF12$`연령대`=='40대',3,ifelse(selected_DF12$`연령대`=='50대',4,
ifelse(selected_DF12$`연령대`=='60대',5,ifelse(selected_DF12$`연령대`=='70대이상',6,7)))))))

# %%
selected_DF12
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대 이용건수
# 1     2022-12-01 1260       1            NA   0      1
# 2     2022-12-01 1264       1            NA   0      1
# 3     2022-12-01 1265       1            NA   0      1
# 4     2022-12-01 1269       1            NA   0      1
# 5     2022-12-01 1274       1            NA   0      1
# 6     2022-12-01 1277       1            NA   0      2
# 7     2022-12-01 1282       1            NA   0      1
# 8     2022-12-01 1288       1            NA   0      1
# 9     2022-12-01 1291       1            NA   0      1
# 10    2022-12-01 1299       1            NA   0      1
# 11    2022-12-01 2601       1            NA   0      1
# 12    2022-12-01 2608       1            NA   0      1
# 13    2022-12-01 2611       1            NA   0      1
# 14    2022-12-01 2615       1            NA   0      1
# 15    2022-12-01 2644       1            NA   0      1
# 16    2022-12-01 2630       1            NA   0      1
# ...

# %%
write.csv(selected_DF12,file="/content/전처리_송파구_서울특별시 공공자전거 이용정보(일별)_22.12.csv",row.names=FALSE, na="")

# %%
selected_DF12$'평일/주말' <- ifelse(selected_DF12$대여일자 %in% date$date_time, date$weekend[match(selected_DF12$대여일자, date$date_time)], 2)
selected_DF12
# Out:
#       대여일자   대여소번호 대여구분코드 성별 연령대 이용건수 평일/주말
# 1     2022-12-01 1260       1            NA   0      1        0
# 2     2022-12-01 1264       1            NA   0      1        0
# 3     2022-12-01 1265       1            NA   0      1        0
# 4     2022-12-01 1269       1            NA   0      1        0
# 5     2022-12-01 1274       1            NA   0      1        0
# 6     2022-12-01 1277       1            NA   0      2        0
# 7     2022-12-01 1282       1            NA   0      1        0
# 8     2022-12-01 1288       1            NA   0      1        0
# 9     2022-12-01 1291       1            NA   0      1        0
# 10    2022-12-01 1299       1            NA   0      1        0
# 11    2022-12-01 2601       1            NA   0      1        0
# 12    2022-12-01 2608       1            NA   0      1        0
# 13    2022-12-01 2611       1            NA   0      1        0
# 14    2022-12-01 2615       1            NA   0      1        0
# ...

# %%
selected_DF12 <- selected_DF12 %>% select('평일/주말', '대여구분코드', '성별', '연령대', '이용건수')
selected_DF12
# Out:
#       평일/주말 대여구분코드 성별 연령대 이용건수
# 1     0         1            NA   0      1
# 2     0         1            NA   0      1
# 3     0         1            NA   0      1
# 4     0         1            NA   0      1
# 5     0         1            NA   0      1
# 6     0         1            NA   0      2
# 7     0         1            NA   0      1
# 8     0         1            NA   0      1
# 9     0         1            NA   0      1
# 10    0         1            NA   0      1
# 11    0         1            NA   0      1
# 12    0         1            NA   0      1
# 13    0         1            NA   0      1
# 14    0         1            NA   0      1
# 15    0         1            NA   0      1
# 16    0         1            NA   0      1
# 17    0         1            NA   0      1
# 18    0         1            NA   0      1
# 19    0         1            NA   0      1
# 20    0         1            NA   0      2
# 21    0         1            NA   0      2
# ...

# %%
summarized_data_12 <- selected_DF12 %>%
  group_by(대여일자) %>%
  summarise(이용건수_합계 = sum(이용건수, na.rm = TRUE))

summarized_data_12
# Out:
#    대여일자   이용건수_합계
# 1  2022-12-01 6622
# 2  2022-12-02 7477
# 3  2022-12-03 5605
# 4  2022-12-04 4245
# 5  2022-12-05 7054
# 6  2022-12-06 6962
# 7  2022-12-07 8637
# 8  2022-12-08 9114
# 9  2022-12-09 9603
# 10 2022-12-10 6910
# 11 2022-12-11 5684
# 12 2022-12-12 5478
# 13 2022-12-13 5050
# 14 2022-12-14 4975
# 15 2022-12-15 3565
# 16 2022-12-16 4202
# 17 2022-12-17 3226
# 18 2022-12-18 2359
# 19 2022-12-19 4995
# 20 2022-12-20 6058
# 21 2022-12-21 2516
# 22 2022-12-22 2750
# 23 2022-12-23 2487
# 24 2022-12-24 2297
# 25 2022-12-25 2090
# 26 2022-12-26 4235
# 27 2022-12-27 4825
# 28 2022-12-28 4536
# 29 2022-12-29 4986
# 30 2022-12-30 4680
# 31 2022-12-31 3713

# %% [markdown]
# ## **일자별 0/1파일**

# %%
#https://drive.google.com/file/d/1JlXF_LH5XdOvcfjdbFAqyhn2QUJJYUgz/view?usp=sharing
system("gdown --id 1JlXF_LH5XdOvcfjdbFAqyhn2QUJJYUgz")
system("ls",TRUE)
# Out:
# [1] "서울특별시 공공자전거 이용정보(일별)_22.01.csv"
# [2] "일자별 날씨정보.csv"
# [3] "sample_data"

# %%
date<- read_csv("/content/일자별 날씨정보.csv", locale = locale('ko',encoding = 'cp949'))%>% as_tibble()
date
# Out:
# Rows: 365 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (7): rain, wind_speed, humidity, avrage_temp, weekend, discomfort_index...
# date (1): date_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     date_time  rain wind_speed humidity avrage_temp weekend discomfort_index
# 1   2022-01-01 0    1.5        46.3     -4.3        1       34.2
# 2   2022-01-02 1    2.3        57.9     -1.3        1       36.2
# 3   2022-01-03 0    1.8        58.3     -1.9        0       35.3
# 4   2022-01-04 0    2.4        51.8     -2.5        0       35.6
# 5   2022-01-05 0    1.7        47.6     -2.8        0       35.9
# 6   2022-01-06 0    2.3        47.1     -2.2        0       36.8
# 7   2022-01-07 0    1.5        47.1     -1.6        0       37.5
# ...

# %%
date<- date%>% select(c(date_time, weekend))
date
# Out:
#     date_time  weekend
# 1   2022-01-01 1
# 2   2022-01-02 1
# 3   2022-01-03 0
# 4   2022-01-04 0
# 5   2022-01-05 0
# 6   2022-01-06 0
# 7   2022-01-07 0
# 8   2022-01-08 1
# 9   2022-01-09 1
# 10  2022-01-10 0
# 11  2022-01-11 0
# 12  2022-01-12 0
# 13  2022-01-13 0
# 14  2022-01-14 0
# 15  2022-01-15 1
# 16  2022-01-16 1
# 17  2022-01-17 0
# 18  2022-01-18 0
# 19  2022-01-19 0
# 20  2022-01-20 0
# 21  2022-01-21 0
# 22  2022-01-22 1
# 23  2022-01-23 1
# 24  2022-01-24 0
# 25  2022-01-25 0
# 26  2022-01-26 0
# 27  2022-01-27 0
# 28  2022-01-28 0
# 29  2022-01-29 1
# 30  2022-01-30 1
# ⋮   ⋮          ⋮
# 336 2022-12-02 0
# 337 2022-12-03 1
# 338 2022-12-04 1
# 339 2022-12-05 0
# 340 2022-12-06 0
# 341 2022-12-07 0
# 342 2022-12-08 0
# 343 2022-12-09 0
# 344 2022-12-10 1
# 345 2022-12-11 1
# 346 2022-12-12 0
# 347 2022-12-13 0
# 348 2022-12-14 0
# 349 2022-12-15 0
# 350 2022-12-16 0
# 351 2022-12-17 1
# 352 2022-12-18 1
# 353 2022-12-19 0
# 354 2022-12-20 0
# 355 2022-12-21 0
# ...

# %% [markdown]
# ## **1월 사용량**

# %%
selected_DF01$'평일/주말' <- ifelse(selected_DF01$대여일자 %in% date$date_time, date$weekend[match(selected_DF01$대여일자, date$date_time)], 2)
selected_DF01
# Out:
# Warning message:
# “Unknown or uninitialised column: `대여일자`.”
# Error in `$<-`:
# ! Assigned data `ifelse(...)` must be compatible with existing data.
# ✖ Existing data has 66072 rows.
# ✖ Assigned data has 0 rows.
# ℹ Only vectors of size 1 are recycled.
# Caused by error in `vectbl_recycle_rhs_rows()`:
# ! Can't recycle input of size 0 to size 66072.
# Traceback:
#
# 1. `$<-`(`*tmp*`, "평일/주말", value = logical(0))
# 2. `$<-.tbl_df`(`*tmp*`, "평일/주말", value = logical(0))
# 3. tbl_subassign(x, i = NULL, as_string(name), list(value), i_arg = NULL,
#  .     j_arg = name, value_arg = substitute(value))
# 4. vectbl_recycle_rhs_rows(value, fast_nrow(xo), i_arg = NULL, value_arg,
#  .     call)
# 5. withCallingHandlers(for (j in seq_along(value)) {
#  .     if (!is.null(value[[j]])) {
#  .         value[[j]] <- vec_recycle(value[[j]], nrow)
#  .     }
#  . }, vctrs_error_recycle_incompatible_size = function(cnd) {
#  .     abort_assign_incompatible_size(nrow, value, j, i_arg, value_arg,
# ...

# %%
selected_DF01 <- selected_DF01 %>% select('평일/주말', '대여구분코드', '성별', '연령대코드', '이용건수')
selected_DF01
# Out:
#       평일/주말 대여구분코드 성별 연령대코드 이용건수
# 1     1         0            NA   4          1
# 2     1         1             2   1          4
# 3     1         1             2   2          2
# 4     1         1             2   3          1
# 5     1         1             2   4          1
# 6     1         1            NA   1          1
# 7     1         1             1   1          1
# 8     1         1             1   2          1
# 9     1         1             1   3          1
# 10    1         1             1   7          2
# 11    1         1             0   1          1
# 12    1         1             0   2          2
# 13    1         1             0   4          1
# 14    1         1             0   7          1
# 15    1         0             2   0          1
# 16    1         0             2   1          1
# 17    1         0             1   4          1
# 18    1         0             0   2          1
# 19    1         0             0   3          1
# ...

# %%
selected_DF01$'사용량'<-
